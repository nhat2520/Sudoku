# %% [markdown]
# <a href="https://colab.research.google.com/github/nhat2520/Sudoku/blob/master/Colaboratory_ch%C3%A0o_m%E1%BB%ABng_b%E1%BA%A1n!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Chào mừng bạn đến với Colab!</h1>
# </div>
#
# Nếu bạn đã quen dùng Colab, hãy xem video này để tìm hiểu về các bảng tương tác, chế độ xem lịch sử thực thi mã và bảng lệnh.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Hình thu nhỏ của một video cho thấy 3 tính năng thú vị của Google Colab' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>Colab là gì?</h2>
# </div>
#
# Colab &#40;hay còn gọi là "Colaboratory"&#41; cho phép bạn viết và thực thi Python trong trình duyệt với các lợi ích sau:
# - Không yêu cầu cấu hình
# - Quyền truy cập miễn phí vào GPU
# - Chia sẻ dễ dàng
#
# Cho dù bạn là <strong>sinh viên</strong>, <strong>nhà khoa học dữ liệu</strong> hay <strong>nhà nghiên cứu AI &#40;trí tuệ nhân tạo&#41;</strong>, Colab đều giúp bạn hoàn thành công việc dễ dàng hơn. Hãy xem phần <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Hướng dẫn về Colab</a> để tìm hiểu thêm hoặc bắt đầu ngay ở bên dưới!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>Bắt đầu</strong>
# </div>
#
# Tài liệu bạn đang đọc không phải là trang web tĩnh, mà là một môi trường tương tác được gọi là <strong>sổ tay trên Colab</strong>. Trên đó, bạn có thể viết và thực thi mã.
#
# Ví dụ: sau đây là một <strong>ô chứa mã</strong> có tập lệnh Python ngắn tính toán một giá trị, lưu trữ giá trị đó trong một biến và in kết quả:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Để thực thi mã trong ô trên, hãy nhấp để chọn mã đó rồi nhấn nút phát ở bên trái mã hoặc sử dụng tổ hợp phím tắt "Command/Ctrl+Enter". Để chỉnh sửa mã này, bạn chỉ cần nhấp vào ô đó và bắt đầu chỉnh sửa.
#
# Các biến mà bạn xác định trong một ô có thể dùng trong các ô khác sau này:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Sổ tay trên Colab cho phép bạn kết hợp <strong>mã có thể thực thi</strong> và <strong>văn bản đa dạng thức</strong> trong một tài liệu duy nhất, cùng với <strong>hình ảnh</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> và nhiều nội dung khác. Khi bạn tạo sổ tay của riêng mình trên Colab, các sổ tay đó sẽ được lưu trữ trong tài khoản Google Drive của bạn. Bạn có thể dễ dàng chia sẻ sổ tay của mình trên Colab với đồng nghiệp hoặc bạn bè, cho phép họ nhận xét hoặc thậm chí là chỉnh sửa các sổ tay đó. Để tìm hiểu thêm, hãy xem phần <a href="/notebooks/basic_features_overview.ipynb">Tổng quan về Colab</a>. Để tạo một sổ tay mới trên Colab, bạn có thể sử dụng trình đơn Tệp ở trên hoặc sử dụng đường liên kết sau: <a href="http://colab.research.google.com#create=true">tạo một sổ tay mới trên Colab</a>.
#
# Sổ tay trên Colab là các sổ tay Jupyter được Colab lưu trữ. Để tìm hiểu thêm về dự án Jupyter, hãy xem <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Khoa học dữ liệu
# </div>
#
# Với Colab, bạn có thể khai thác toàn bộ sức mạnh của các thư viện Python phổ biến để phân tích và trực quan hóa dữ liệu. Ô chứa mã ở bên dưới sử dụng <strong>numpy</strong> để tạo một số dữ liệu ngẫu nhiên và sử dụng <strong>matplotlib</strong> để trực quan hóa dữ liệu đó. Để chỉnh sửa mã này, bạn chỉ cần nhấp vào ô đó và bắt đầu chỉnh sửa.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# Bạn có thể nhập dữ liệu của riêng mình vào các sổ tay trên Colab từ tài khoản Google Drive, bao gồm từ bảng tính, cũng như từ GitHub và nhiều nguồn khác. Để tìm hiểu thêm về cách nhập dữ liệu và cách áp dụng Colab cho ngành khoa học dữ liệu, hãy xem các đường liên kết trong phần <a href="#working-with-data">Làm việc với dữ liệu</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Máy học
# </div>
#
# Với Colab, chỉ cần sử dụng <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">một vài dòng mã</a> là bạn có thể nhập tập dữ liệu hình ảnh, huấn luyện một trình phân loại hình ảnh dựa trên tập dữ liệu đó và đánh giá mô hình này. Sổ tay trên Colab thực thi mã trên các máy chủ đám mây của Google. Nhờ đó, bạn có thể tận dụng sức mạnh của phần cứng Google, bao gồm cả <a href="#using-accelerated-hardware">GPU và TPU</a>, cho dù máy tính của bạn sử dụng sức mạnh phần cứng nào. Bạn chỉ cần một trình duyệt.

# %% [markdown]
# Colab được sử dụng rộng rãi trong cộng đồng máy học với các ứng dụng như:
# - Bắt đầu sử dụng TensorFlow
# - Phát triển và huấn luyện mạng nơron
# - Thử nghiệm có sử dụng TPU
# - Phổ biến nghiên cứu về AI &#40;trí tuệ nhân tạo&#41;
# - Tạo hướng dẫn
#
# Để xem các sổ tay mẫu trên Colab minh họa các ứng dụng dùng mô hình máy học, hãy xem <a href="#machine-learning-examples">các ví dụ về máy học</a> ở bên dưới.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Tài nguyên khác
#
# ### Làm việc với Sổ tay trong Colab
#
# </div>
#
# - [Tổng quan về Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Hướng dẫn sử dụng Markdown](/notebooks/markdown_guide.ipynb)
# - [Nhập thư viện và cài đặt phần phụ thuộc](/notebooks/snippets/importing_libraries.ipynb)
# - [Lưu và tải sổ tay trong GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Biểu mẫu tương tác](/notebooks/forms.ipynb)
# - [Tiện ích tương tác](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Làm việc với dữ liệu
# </div>
#
# - [Tải dữ liệu: Drive, Trang tính và Google Cloud Storage](/notebooks/io.ipynb)
# - [Biểu đồ: trực quan hóa dữ liệu](/notebooks/charts.ipynb)
# - [Bắt đầu sử dụng BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Khóa học máy học ứng dụng
#
# <div>
#
# Khóa học trực tuyến của Google về Máy học có cung cấp một số sổ tay. Hãy xem <a href="https://developers.google.com/machine-learning/crash-course/">trang web của toàn bộ khóa học</a> để biết thêm thông tin.
# - [Giới thiệu về Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Hồi quy tuyến tính bằng tf.keras sử dụng dữ liệu tổng hợp](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Sử dụng phần cứng tăng tốc
# </div>
#
# - [TensorFlow có GPU](/notebooks/gpu.ipynb)
# - [TensorFlow có TPU](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Ví dụ điển hình
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">Ứng dụng hoán đổi giọng nói NeMo</a>: Dùng Bộ công cụ AI &#40;trí tuệ nhân tạo&#41; NeMo có khả năng trò chuyện của Nvidia để hoán đổi giọng nói trong một đoạn âm thanh với giọng nói do máy tính tạo.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Huấn luyện lại trình phân loại hình ảnh</a>: Tạo một mô hình Keras cùng với trình phân loại hình ảnh đã được huấn luyện trước để phân biệt các loại hoa.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Phân loại văn bản</a>: Phân loại các bài đánh giá phim trên IMDB là <em>tích cực</em> hoặc <em>tiêu cực</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Sao chép phong cách</a>: Sử dụng mô hình học sâu để sao chép phong cách giữa các hình ảnh.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Hỏi và đáp về Bộ mã hóa câu tổng quát đa ngôn ngữ</a>: Sử dụng một mô hình máy học để giải đáp các câu hỏi từ tập dữ liệu SQuAD.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Nội suy video</a>: Dự đoán những điều đã xảy ra trong một video từ khung hình đầu tiên đến khung hình cuối cùng.

# %%
# %pip install facebook_scraper pandas numpy
# Out:
# Collecting facebook_scraper
#   Downloading facebook_scraper-0.2.59-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Collecting dateparser<2.0.0,>=1.0.0 (from facebook_scraper)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 7.5 MB/s eta 0:00:00
# Collecting demjson3<4.0.0,>=3.0.5 (from facebook_scraper)
#   Downloading demjson3-3.0.6.tar.gz (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.5/131.5 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting requests-html<0.11.0,>=0.10.0 (from facebook_scraper)
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser<2.0.0,>=1.0.0->facebook_scraper) (2023.6.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser<2.0.0,>=1.0.0->facebook_scraper) (5.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.31.0)
# Collecting pyquery (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting fake-useragent (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading fake_useragent-1.4.0-py3-none-any.whl (15 kB)
# Collecting parse (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading parse-1.19.1-py2.py3-none-any.whl (18 kB)
# Collecting bs4 (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting w3lib (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Collecting pyppeteer>=0.0.14 (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.4.4)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (2023.7.22)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (6.8.0)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.66.1)
# Collecting urllib3<2.0.0,>=1.25.8 (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 9.5 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.11.2)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.9.3)
# Collecting cssselect>=1.2.0 (from pyquery->requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook_scraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook_scraper) (3.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (3.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.5)
# Building wheels for collected packages: demjson3, bs4
#   Building wheel for demjson3 (setup.py) ... done
#   Created wheel for demjson3: filename=demjson3-3.0.6-py3-none-any.whl size=75281 sha256=c0b2d24330d141213450a64aa3899b9f8112a08b95e3ed0dd749dcb5617d22f6
#   Stored in directory: /root/.cache/pip/wheels/2d/32/af/75c810e14c7ca0df40c20c662fcc7f33d1e055937b4e452cc1
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=d8c17f13fcb526069ba7545c522faf989ac745cf127e24fb8f632859122c5b6b
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built demjson3 bs4
# Installing collected packages: pyee, parse, fake-useragent, demjson3, websockets, w3lib, urllib3, cssselect, pyquery, pyppeteer, dateparser, bs4, requests-html, facebook_scraper
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed bs4-0.0.1 cssselect-1.2.0 dateparser-1.2.0 demjson3-3.0.6 facebook_scraper-0.2.59 fake-useragent-1.4.0 parse-1.19.1 pyee-8.2.2 pyppeteer-1.0.2 pyquery-2.0.0 requests-html-0.10.0 urllib3-1.26.18 w3lib-2.1.2 websockets-10.4

# %%
from facebook_scraper import get_posts
import facebook_scraper as fs
import pandas as pd
import numpy as np
import time
import pprint
import random

# %%
for i in range(4):
  number = random.randint(15,30) * 2
  time.sleep(number)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-cc793d584aad> in <cell line: 1>()
#       1 for i in range(4):
#       2   number = random.randint(15,30) * 2
# ----> 3   time.sleep(number)
#
# KeyboardInterrupt:

# %%
FANPAGE_LINK ="GOAL"
FOLDER_PATH = "Data/"
COOKIE_PATH = "./cookies.txt"

PAGES_NUMBER = 80 # Number of pages to crawl

# %%
post_id_list =

# %%
post_list2 = pd.read_csv('./GOAL.csv')

# %%
len(post_list2)
# Out:
# 239

# %%
count = 239
for i in range(239,1000):
  print(count)
  gen =  fs.get_posts(
      post_urls=[post_id_list[i]],
      options={"comments":True,  "reactions": True, "allow_extra_requests": True},
      cookies=COOKIE_PATH
  )
  post = next(gen)
  if post['reactions'] == None or post['comments_full'] == None:
    break
  post_list = post_list.append(post, ignore_index=True)
  count += 1
# Out:
# 239
# ---------------------------------------------------------------------------
# TemporarilyBanned                         Traceback (most recent call last)
# <ipython-input-29-963edcdaf069> in <cell line: 2>()
#       7       cookies=COOKIE_PATH
#       8   )
# ----> 9   post = next(gen)
#      10   if post['reactions'] == None or post['comments_full'] == None:
#      11     break
#
# /usr/local/lib/python3.10/dist-packages/facebook_scraper/facebook_scraper.py in get_posts_by_url(self, post_urls, options, remove_source)
#     127             post = {"original_request_url": post_url, "post_url": url}
#     128             logger.debug(f"Requesting page from: {url}")
# --> 129             response = self.get(url)
#     130             options["response_url"] = response.url
#     131             photo_post = False
#
# /usr/local/lib/python3.10/dist-packages/facebook_scraper/facebook_scraper.py in get(self, url, **kwargs)
#     927                     raise exceptions.UnexpectedResponse("Your request couldn't be processed")
#     928                 elif title.text.lower() in temp_ban_titles:
# --> 929                     raise exceptions.TemporarilyBanned(title.text)
#     930                 elif ">your account has been disabled<" in response.html.html.lower():
#     931                     raise exceptions.AccountDisabled("Your Account Has Been Disabled")
#
# TemporarilyBanned: You’re Temporarily Blocked

# %%
len(post_list)
# Out:
# 239

# %%
post_list
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py:700: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# /usr/local/lib/python3.10/dist-packages/google/colab/_interactive_table_hint_button.py:178: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_html=dataframe._repr_html_(),  # pylint: disable=protected-access
#              v=0'                                    'type': 'like'}  \
# 0    9.052758e+14  https://facebook.com/story.php?story_fbid=pfbi...
# 1    9.052590e+14  https://facebook.com/story.php?story_fbid=pfbi...
# 2    9.052397e+14  https://facebook.com/story.php?story_fbid=pfbi...
# 3    9.052304e+14  https://facebook.com/story.php?story_fbid=pfbi...
# 4    9.052245e+14  https://facebook.com/story.php?story_fbid=pfbi...
# ..            ...                                                ...
# 140           NaN                                                NaN
# 141           NaN                                                NaN
# 142           NaN                                                NaN
# 143           NaN                                                NaN
# 144           NaN                                                NaN
#
#                           {'name': 'Askhat Nasirdinov'  \
# 0    pfbid05tSbiLg68bYbUqJayit9usVyZhpZtRpowbgg4Lex...
# 1    pfbid0qhynLpsD9WNNjM1y37e2paXHnzjkGJU7KqvmeZro...
# 2    pfbid02icapQvEvhyK5Vi2symwb24PPxp4Gd1DJXz3jb3L...
# 3    pfbid02NLAxqnEeK28hRr6fY4mBUDuxNNFGDNQnFPBX9XA...
# 4    pfbid02RFtHij6QzjJhqN8aZXDMyd3hdoWyaTwc3gGh9AE...
# ..                                                 ...
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
#
#      'link': 'https://facebook.com/profile.php?id=100007515196976&eav=AfYHUkIYk4eJQBUVE6Iy3paZjptBOxrN_P_aV_nIfzcOLmTlQsXADGMLae4dKe4XcT4&fref=pb&paipv=0'  \
# 0    Another points deduction could spell disaster ...
# 1    John Obi Mikel played against Lionel Messi and...
# 2    Erling Haaland faces a race to be fit for Man ...
# 3    Football winner stays on, goalkeepers edition:...
# 4    Lauren James single-handedly destroyed Liverpo...
# ..                                                 ...
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
#
#                                      'type': 'like'}.1  \
# 0    Another points deduction could spell disaster ...
# 1    John Obi Mikel played against Lionel Messi and...
# 2    Erling Haaland faces a race to be fit for Man ...
# 3    Football winner stays on, goalkeepers edition:...
# 4    Lauren James single-handedly destroyed Liverpo...
# ..                                                 ...
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
#
#                         {'name': 'Yegon Kipsang Peter'  \
# 0    GOAL.COM\nWhy Everton could face ANOTHER point...
# 1                                                  NaN
# 2    GOAL.COM\nErling Haaland gives injury update a...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
#
#       'link': 'https://facebook.com/yegon.peter.16?eav=AfbZVqZ5gYGLMOnaDOyK4sfTX8bD08pgFMwTHJir-bF7PReK89HOWDJhAXsNtwidA70&fref=pb&paipv=0'  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
#
#        'type': 'like'}.2   {'name': 'Bhoms Marazo Shandu'  \
# 0    2023-11-18 17:51:50                     1.700330e+09
# 1    2023-11-18 17:07:23                     1.700327e+09
# 2    2023-11-18 16:24:47                     1.700325e+09
# 3    2023-11-18 16:02:03                     1.700323e+09
# 4    2023-11-18 15:48:29                     1.700323e+09
# ..                   ...                              ...
# 140                  NaN                              NaN
# 141                  NaN                              NaN
# 142                  NaN                              NaN
# 143                  NaN                              NaN
# 144                  NaN                              NaN
#
#      'link': 'https://facebook.com/xolanibhoms.shandu?eav=AfbM5wgZ_juCcO-fxTdyqkNQqQj7Grc2oPPb74fStdc-BC8lNyNbNh_FT-kuO_PQIyw&fref=pb&paipv=0'  \
# 0                                                  NaN
# 1    https://scontent-atl3-2.xx.fbcdn.net/v/t39.308...
# 2                                                  NaN
# 3                                                  NaN
# 4    https://scontent-atl3-2.xx.fbcdn.net/v/t39.308...
# ..                                                 ...
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
#
#      ... reaction_count  with      page_id sharers image_id image_ids  \
# 0    ...            NaN   NaN          NaN     NaN      NaN       NaN
# 1    ...            NaN   NaN          NaN     NaN      NaN       NaN
# 2    ...            NaN   NaN          NaN     NaN      NaN       NaN
# 3    ...            NaN   NaN          NaN     NaN      NaN       NaN
# 4    ...            NaN   NaN          NaN     NaN      NaN       NaN
# ..   ...            ...   ...          ...     ...      ...       ...
# 140  ...         3098.0  None  25427813597    None     None        []
# 141  ...         3322.0  None  25427813597    None     None        []
# 142  ...          823.0  None  25427813597    None     None        []
# 143  ...         2325.0  None  25427813597    None     None        []
# 144  ...         1098.0  None  25427813597    None     None        []
#
#      was_live               fetched_time  video_ids  videos
# 0         NaN                        NaT        NaN     NaN
# 1         NaN                        NaT        NaN     NaN
# 2         NaN                        NaT        NaN     NaN
# 3         NaN                        NaT        NaN     NaN
# 4         NaN                        NaT        NaN     NaN
# ..        ...                        ...        ...     ...
# 140     False 2023-11-25 02:16:14.482647        NaN     NaN
# 141     False 2023-11-25 02:16:16.901768        NaN     NaN
# 142     False 2023-11-25 02:16:19.579911        NaN     NaN
# 143     False 2023-11-25 02:16:21.104081        NaN     NaN
# 144     False 2023-11-25 02:16:22.840150        NaN     NaN
#
# [145 rows x 16227 columns]

# %%
for i in range(166, 239):
  print(post_list.iloc[i]['comments_full'])
# Out:
# [{'comment_id': '1514105049345888', 'comment_url': 'https://facebook.com/1514105049345888', 'commenter_id': '100000175826757', 'commenter_url': 'https://facebook.com/hilary.dixon.71?eav=AfYCTc-OGGI-jYiU0UfGYfF61nKNkZbxyM5-_o8R5UIWSzfcgqTEmTkTT1X-7LTbgT0&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': '
fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0', 'commenter_name': 'Unah Chigozie Ogbonna David', 'commenter_meta': 'Top fan', 'comment_text': 'Rest In Peace sir Bobby 🛌', 'comment_time': datetime.datetime(2023, 11, 11, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}]
# []
# []
# []
# []
# []
# []
# []
# [{'comment_id': '193272750492857', 'comment_url': 'https://facebook.com/193272750492857', 'commenter_id': '61553726750426', 'commenter_url': 'https://facebook.com/profile.php?id=61553726750426&eav=AfbaMf22xnO01RLTbdbfDbK4ihf6uyQekQR1UZywknASFPKEacEhdWwYBnrm16HHAIE&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0', 'commenter_name': 'DRAW KING', 'commenter_meta': None, 'comment_text': 'To everyone reading this I’m a tipstar I give sure football betting tips and i wish to be followed my you all 🙏', 'comment_time': datetime.datetime(2023, 11, 11, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}]
# []
# []
# []
# []
# []
# [{'comment_id': '882012786607274', 'comment_url': 'https://facebook.com/882012786607274', 'commenter_id': '100015281175218', 'commenter_url': 'https://facebook.com/luke.kidd.7792?eav=AfaVxnxroX8qcdynTf9USPwBDqYmiT2wxiSEXM4_FxVCRO9lfwEXTKEyG0fjLc93P4U&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Cyrus JF', 'commenter_meta': None, 'comment_text': "Mata Is good but I like Villa better ;hazard could play like a 9 but he is more like a 10 so that's definitely something you need in a team specially if you already have an striker", 'comment_time': datetime.datetime(2023, 11, 24, 19, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': [{'comment_id': '24215529154759064', 'comment_url': 'https://facebook.com/24215529154759064', 'commenter_id': '100015281175218', 'commenter_url': 'https://facebook.com/luke.kidd.7792?eav=AfYcj36DthzVuj-PwHZBTg-pYXLLSAY2ZYSyKgYSsGLesRIu2vDo-TX6VBtIIRMD7kY&fref=nf&rc=p&__tn__=R&paipv=0', 'commenter_name': 'Cyrus JF', 'commenter_meta': None, 'comment_text': 'I also think mata and Villa played different positions', 'comment_time': datetime.datetime(2023, 11, 24, 19, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None}, {'comment_id': '6919314511481694', 'comment_url': 'https://facebook.com/6919314511481694', 'commenter_id': '100015281175218', 'commenter_url': 'https://facebook.com/luke.kidd.7792?eav=AfYcj36DthzVuj-PwHZBTg-pYXLLSAY2ZYSyKgYSsGLesRIu2vDo-TX6VBtIIRMD7kY&fref=nf&rc=p&__tn__=R&paipv=0', 'commenter_name': 'Cyrus JF', 'commenter_meta': None, 'comment_text': 'Not sure', 'comment_time': datetime.datetime(2023, 11, 24, 19, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None}]}]
# []
# []
# []
# []
# [{'comment_id': '984311972868546', 'comment_url': 'https://facebook.com/984311972868546', 'commenter_id': '100000993880990', 'commenter_url': 'https://facebook.com/baptiste.j.hernandez?eav=AfbZPvdIhQc0IA383Q5sjieyKCjsyBJWpg0FDRPPjD_SF0E08ICZHSqg8oGmbrmwBwk&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Baptiste Julio Hernandez', 'commenter_meta': 'Top fan', 'comment_text': "Let's young coaches teach the lesson.", 'comment_time': datetime.datetime(2023, 11, 11, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}]
# []
# []
# []
# []
# [{'comment_id': '1540911206677593', 'comment_url': 'https://facebook.com/1540911206677593', 'commenter_id': '100065244513311', 'commenter_url': 'https://facebook.com/arabienboyy.suparsevventysevven?eav=AfbcfU3lTeyMybCmTCwgJO1DMkUS7i2Cctvk4UWKzhZXbKz4ZwoCq8Nnps6iZ8b78z4&fref=nf&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Arabienboyy Supar Sevventy Sevven', 'commenter_meta': None, 'comment_text': 'If this boy Join Madrid Vini is not stopping the dance celebration', 'comment_time': datetime.datetime(2023, 11, 11, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}, {'comment_id':
'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}, {'comment_id': '673405328190494', 'comment_url': 'https://facebook.com/673405328190494', 'commenter_id': '100002884787645', 'commenter_url': 'https://facebook.com/yongjin.choi.520?eav=AfZYQP4GqjahNj5pGUoUSWoYGeUXgPNnd4IOywcKb33ZNfH5NYWIaF_lpy-U39TIPGU&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Yong Jin Choi', 'commenter_meta': None, 'comment_text': 'Yong Jin Choi', 'comment_time': datetime.datetime(2023, 11, 11, 0, 0), 'comment_image': 'https://scontent-sjc3-1.xx.fbcdn.net/v/t39.1997-6/365229148_304530232070680_5856242784050230266_n.webp?stp=cp0_dst-png_s110x80&_nc_cat=106&ccb=1-7&_nc_sid=fc3f23&efg=eyJpIjoidCJ9&_nc_ohc=bT0mN6lWVLsAX9Qh1z7&_nc_ht=scontent-sjc3-1.xx&oh=00_AfBP99y3o6g2GgbHN5kiQl2E5HjJMt00jQM25yGSwbKOjA&oe=656592AE', 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}]
# [{'comment_id': '193438103807636', 'comment_url': 'https://facebook.com/193438103807636', 'commenter_id': '100005733459960', 'commenter_url': 'https://facebook.com/chrizz.enrique?eav=AfY901c1mzjfNFvlssG19WUKEB2POvKv-agycfYGYk0Ss-vtxwkhmvNj3phmQqw5dJA&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Wah Krizna', 'commenter_meta': 'Top fan', 'comment_text': 'Without referee they are nothing', 'comment_time': datetime.datetime(2023, 11, 11, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}]
# [{'comment_id': '878437607146637', 'comment_url': 'https://facebook.com/878437607146637', 'commenter_id': '100003330740041', 'commenter_url': 'https://facebook.com/akintomide.olawale1?eav=AfZG5LSjrB8ApDGxjDDPw3I0smUCX9Lp5KjrhZpzoGIU3RU0tKN8p4JiAyvg9UhcPv8&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0', 'commenter_name': 'Akintomide Olawale', 'commenter_meta': None, 'comment_text': 'What is being covered on his head?', 'comment_time': datetime.datetime(2023, 11, 11, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}]
# [{'comment_id': '1529114724494781', 'comment_url': 'https://facebook.com/1529114724494781', 'commenter_id': '100091655326338', 'commenter_url': 'https://facebook.com/profile.php?id=100091655326338&eav=AfYtmPVXAx4qQhP5v-jKP0a-dxnjkES16W7mqicHP_WtZe1EzH6MvQwi_5rz9uSFH3Y&fref=nf&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Muhammad Abideen Oladapo', 'commenter_meta': None, 'comment_text': 'KB(9)', 'comment_time': datetime.datetime(2023, 11, 11, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}, {'comment_id': '319701040809869', 'comment_url': 'https://facebook.com/319701040809869', 'commenter_id': '100010732327887', 'commenter_url': 'https://facebook.com/profile.php?id=100010732327887&eav=Afbff4uc_QxLrJsmMBNY8Q5dUkuRw6fMBHCY6_FSgkL0crtOmSLcFWY0nEcjrmPIC4A&fref=nf&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Neoson Thomas Kunda', 'commenter_meta': None, 'comment_text': 'What a player he is', 'comment_time': datetime.datetime(2023, 11, 11, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}]
# []

# %%
post_list = post_list.append(post, ignore_index = True)
# Out:
# <ipython-input-37-92ad89dba139>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   post_list = post_list.append(post, ignore_index = True)

# %%
post_list

# %%
#post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)
post_list.to_csv('./GOAL.csv', index=False)
